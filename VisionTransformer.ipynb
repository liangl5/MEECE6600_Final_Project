# %% [markdown]
# ## CIFAR-10 and CIFAR-100
# https://www.cs.toronto.edu/~kriz/cifar.html
#
# baseline results for both CIFAR: http://code.google.com/p/cuda-convnet/

# %%
import torch
from torchvision import datasets
# train_data = datasets.CIFAR10(root='./data', train=True, download=True)
# test_data = datasets.CIFAR10(root='./data', train=False, download=True)
# train_data = datasets.CIFAR100(root='./data', train=True, download=True)
# test_data = datasets.CIFAR100(root='./data', train=False, download=True)

# need to manually read in TinyImageNet
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[36], line 7
#       2 from torchvision import datasets, transforms
#       3 # train_data = datasets.CIFAR10(root='./data', train=True, download=True)
#       4 # test_data = datasets.CIFAR10(root='./data', train=False, download=True)
#       5 # train_data = datasets.CIFAR100(root='./data', train=True, download=True)
#       6 # test_data = datasets.CIFAR100(root='./data', train=False, download=True)
# ----> 7 train_data = datasets.ImageNet(root='./data', train=True)
#       8 test_data = datasets.ImageNet(root='./data', train=False)
#
# File ~\anaconda3\Lib\site-packages\torchvision\datasets\imagenet.py:56, in ImageNet.__init__(self, root, split, **kwargs)
#      53 root = self.root = os.path.expanduser(root)
#      54 self.split = verify_str_arg(split, "split", ("train", "val"))
# ---> 56 self.parse_archives()
# ...

# %%
test_data
# Out:
# Dataset CIFAR100
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
