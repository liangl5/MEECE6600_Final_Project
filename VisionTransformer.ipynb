# %%
# code to read CIFAR=10 and CIFAR-100

# beginning code to unpack .tar.gz
# import shutil
# shutil.unpack_archive("cifar-10-python.tar.gz", "./", format="gztar")
# shutil.unpack_archive("cifar-100-python.tar.gz", "./", format="gztar")

# %%
import torch
